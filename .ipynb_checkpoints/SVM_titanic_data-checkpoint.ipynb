# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("titanic_new.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#to remove column  cabin from data use drop

df.drop("Cabin",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#to replaace nan value with mean of 'Age'col use fill na method

df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
#to remove null values from column

df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.3+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.drop(['PassengerId','Name','Ticket','Fare'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch Embarked
# 0           0       3    male  22.000000      1      0        S
# 1           1       1  female  38.000000      1      0        C
# 2           1       3  female  26.000000      0      0        S
# 3           1       1  female  35.000000      1      0        S
# 4           0       3    male  35.000000      0      0        S
# ..        ...     ...     ...        ...    ...    ...      ...
# 886         0       2    male  27.000000      0      0        S
# 887         1       1  female  19.000000      0      0        S
# 888         0       3  female  29.699118      1      2        S
# 889         1       1    male  26.000000      0      0        C
# 890         0       3    male  32.000000      0      0        Q
#
# [889 rows x 7 columns]

# %%
from sklearn.compose import ColumnTransformer    #coltransformer means to skip steps of coding and use cltransformer 
from sklearn.preprocessing import OrdinalEncoder

# %%
#pass through mean to take all data with it 
ct=ColumnTransformer(transformers=[('Encoder',OrdinalEncoder(),['Sex','Embarked',])],remainder='passthrough')

# %%
x=df.iloc[:,1:]
y=df['Survived']

# %%
x=ct.fit_transform(x)

# %%
x[0]
# Out:
# array([ 1.,  2.,  3., 22.,  1.,  0.])

# %%
x
# Out:
# array([[ 1.        ,  2.        ,  3.        , 22.        ,  1.        ,
#          0.        ],
#        [ 0.        ,  0.        ,  1.        , 38.        ,  1.        ,
#          0.        ],
#        [ 0.        ,  2.        ,  3.        , 26.        ,  0.        ,
#          0.        ],
#        ...,
#        [ 0.        ,  2.        ,  3.        , 29.69911765,  1.        ,
#          2.        ],
#        [ 1.        ,  0.        ,  1.        , 26.        ,  0.        ,
#          0.        ],
#        [ 1.        ,  1.        ,  3.        , 32.        ,  0.        ,
#          0.        ]])

# %%
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch Embarked
# 0           0       3    male  22.000000      1      0        S
# 1           1       1  female  38.000000      1      0        C
# 2           1       3  female  26.000000      0      0        S
# 3           1       1  female  35.000000      1      0        S
# 4           0       3    male  35.000000      0      0        S
# ..        ...     ...     ...        ...    ...    ...      ...
# 886         0       2    male  27.000000      0      0        S
# 887         1       1  female  19.000000      0      0        S
# 888         0       3  female  29.699118      1      2        S
# 889         1       1    male  26.000000      0      0        C
# 890         0       3    male  32.000000      0      0        Q
#
# [889 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
lr=LogisticRegression()
svc=SVC()

# %%
def mymodel(model):
  model.fit(xtrain,ytrain)
  ypred=model.predict(xtest)
  print(classification_report(ytest,ypred))
  return model

# %%
mymodel(lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       166
#            1       0.78      0.78      0.78       101
#
#     accuracy                           0.84       267
#    macro avg       0.82      0.82      0.82       267
# weighted avg       0.84      0.84      0.84       267
# LogisticRegression()

# %%
mymodel(svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.97      0.77       166
#            1       0.62      0.08      0.14       101
#
#     accuracy                           0.63       267
#    macro avg       0.62      0.52      0.45       267
# weighted avg       0.63      0.63      0.53       267
# SVC()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
p1=Pipeline(steps=[('Scaler',StandardScaler()),('svm',SVC()),])

# %%
p1.fit(xtrain,ytrain)
ypred=p1.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.90       166
#            1       0.90      0.71      0.80       101
#
#     accuracy                           0.86       267
#    macro avg       0.87      0.83      0.85       267
# weighted avg       0.87      0.86      0.86       267

# %%
plt.figure(figsize=(7,7))
sns.pairplot(df,hue='Survived')
plt.show()

# %%
#it is a non_linear data
svm=SVC(kernel='linear')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       166
#            1       0.77      0.74      0.76       101
#
#     accuracy                           0.82       267
#    macro avg       0.81      0.81      0.81       267
# weighted avg       0.82      0.82      0.82       267
# SVC(kernel='linear')

# %%
svm=SVC(kernel='poly')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78       166
#            1       1.00      0.09      0.16       101
#
#     accuracy                           0.66       267
#    macro avg       0.82      0.54      0.47       267
# weighted avg       0.78      0.66      0.55       267
# SVC(kernel='poly')

# %%
svm=SVC(kernel='sigmoid')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       166
#            1       0.37      0.35      0.36       101
#
#     accuracy                           0.53       267
#    macro avg       0.49      0.49      0.49       267
# weighted avg       0.52      0.53      0.53       267
# SVC(kernel='sigmoid')

# %%
#hypertuning of c and gamma
from sklearn.model_selection import GridSearchCV
param_grid={'C':[1,10],'gamma':[1,10],'kernel':['rbf']}

# %%
gd=GridSearchCV(svc,param_grid,verbose=3)#verbose (value)  is used to display information
gd.fit(xtrain,ytrain)                    #gridsearchcv is class   and param_grid=parameter
ypred=gd.predict(xtest)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.760 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.806 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=10, kernel=rbf;, score=0.688 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=10, kernel=rbf;, score=0.624 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=10, kernel=rbf;, score=0.669 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=10, kernel=rbf;, score=0.685 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=10, kernel=rbf;, score=0.677 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.784 total time=   0.0s
# ...

# %%
gd.best_params_      #this to find best value
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
